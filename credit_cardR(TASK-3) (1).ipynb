# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn .metrics import classification_report , accuracy_score , confusion_matrix

# %%
card_data = pd.read_csv("creditcard.csv")

# %%
card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
card_data.isnull().sum() #checked  missing values and found none
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#checking how many legit transactions and fraudulent transaction
card_data["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# 284315 transaction is legit and 492 is unbalanced means data set is so much unbalanced

# %%
legit = card_data[card_data.Class==0]
fraudulent = card_data[card_data.Class ==1]

# %%
print(legit.shape)
print(fraudulent.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#checking measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraudulent.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
card_data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
plt.figure(figsize=(10, 5))
sns.histplot(legit.Amount, bins=50, kde=True, label='Legitimate')
sns.histplot(fraudulent.Amount, bins=50, kde=True, color='red', label='Fraudulent')
plt.legend()
plt.title('Transaction Amount Distribution')
plt.show()

# %%
# now we will read with the given unbalanced data
#we will take a sample data set make same amount of legit transaction and fraudulent transaction

# %%
legit_random_sample = legit.sample(n=492)

# %%
#now concatenating two data frames

# %%
joined_dataset = pd.concat([legit_random_sample,fraudulent],axis=0)

# %%
joined_dataset.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 98614    66732.0 -1.058559  1.460607  1.527338  3.391236 -2.061240  3.236678
# 55475    46956.0  1.256722  0.358184  0.304941  0.691706 -0.364424 -1.068944
# 186508  127138.0 -0.563929  1.530381 -0.635552 -0.798500  0.768940 -0.636800
# 153732   99938.0 -2.481563 -0.162909 -0.187367  5.140270  2.159345 -0.284384
# 9361     13656.0  1.259103 -0.170515  0.132158 -0.247662  0.234175  0.901893
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 98614  -2.360480 -5.381451 -0.014042  ...  1.567254 -0.635586  0.220406
# 55475   0.090248 -0.206513  0.024829  ... -0.287351 -0.826559  0.128058
# 186508  0.846103  0.059017  0.246501  ... -0.369835 -0.759523  0.134778
# 153732  0.228052  0.122898 -0.783458  ... -0.126925  1.216561  1.504669
# 9361   -0.607545  0.223960  1.616984  ... -0.373150 -0.912105 -0.040660
#
#              V24       V25       V26       V27       V28  Amount  Class
# 98614   0.006064  0.583114  0.334883  0.485397  0.214801  189.85      0
# 55475   0.341266  0.218609  0.094570 -0.022732  0.030881    1.78      0
# 186508  0.649484 -0.312405  0.100211  0.534529  0.256303    1.29      0
# 153732  0.655431  0.410975  0.720375  0.552303 -0.178181   12.11      0
# 9361   -1.742803  0.085605  0.868892 -0.086833 -0.020240   26.56      0
#
# [5 rows x 31 columns]

# %%
joined_dataset["Class"].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
class_counts = joined_dataset["Class"].value_counts()  # Added this line
plt.figure(figsize=(8, 6))
plt.pie(class_counts, labels=['Legitimate', 'Fraudulent'], autopct='%1.1f%%', startangle=140, colors=['#1f77b4', '#ff7f0e'])
plt.title("Transaction Class Distribution After Balancing")
plt.show()

# %%
joined_dataset.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96687.398374  0.002684 -0.021302  0.029526 -0.049719  0.022856
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.068569  0.028676 -0.026261 -0.099968  ...  0.014980  0.016160
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.006361 -0.045006 -0.026994  0.024337  0.009704  0.020699  0.004006
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       93.696280
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
m = joined_dataset.drop(columns = "Class",axis =0 )
m
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 98614    66732.0 -1.058559  1.460607  1.527338  3.391236 -2.061240  3.236678
# 55475    46956.0  1.256722  0.358184  0.304941  0.691706 -0.364424 -1.068944
# 186508  127138.0 -0.563929  1.530381 -0.635552 -0.798500  0.768940 -0.636800
# 153732   99938.0 -2.481563 -0.162909 -0.187367  5.140270  2.159345 -0.284384
# 9361     13656.0  1.259103 -0.170515  0.132158 -0.247662  0.234175  0.901893
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 98614  -2.360480 -5.381451 -0.014042  ... -0.084461  1.567254 -0.635586
# 55475   0.090248 -0.206513  0.024829  ... -0.077195 -0.287351 -0.826559
# 186508  0.846103  0.059017  0.246501  ...  0.414259 -0.369835 -0.759523
# 153732  0.228052  0.122898 -0.783458  ... -0.806061 -0.126925  1.216561
# 9361   -0.607545  0.223960  1.616984  ... -0.064174 -0.373150 -0.912105
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  1.252967  0.778584 -0.319189
# 280143 -1.413170  0.248525 -1.127396  ...  0.226138  0.370612  0.028234
# 280149 -2.234739  1.210158 -0.652250  ...  0.247968  0.751826  0.834108
# 281144 -2.208002  1.058733 -1.632333  ...  0.306271  0.583276 -0.269209
# 281674  0.223050 -0.068384  0.577829  ... -0.017652 -0.164350 -0.295135
#
#              V23       V24       V25       V26       V27       V28  Amount
# 98614   0.220406  0.006064  0.583114  0.334883  0.485397  0.214801  189.85
# 55475   0.128058  0.341266  0.218609  0.094570 -0.022732  0.030881    1.78
# 186508  0.134778  0.649484 -0.312405  0.100211  0.534529  0.256303    1.29
# 153732  1.504669  0.655431  0.410975  0.720375  0.552303 -0.178181   12.11
# 9361   -0.040660 -1.742803  0.085605  0.868892 -0.086833 -0.020240   26.56
# ...          ...       ...       ...       ...       ...       ...     ...
# 279863  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00
# 280143 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76
# 280149  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89
# 281144 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00
# 281674 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53
#
# [984 rows x 30 columns]

# %%
n = joined_dataset["Class"]
n
# Out:
# 98614     0
# 55475     0
# 186508    0
# 153732    0
# 9361      0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
m_train, m_test , n_train , n_test = train_test_split(m,n,test_size = 0.2,stratify = n,random_state = 2 )

# %%
#now we will train our model (logistic Regression)

# %%
LR = LogisticRegression()
LR.fit(m_train,n_train)
# Out:
# c:\Users\nands\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#now evaluating our model

# %%
#accuracy on training data  

m_train_prediction = LR.predict(m_train)
training_accuracy = accuracy_score(m_train_prediction , n_train)

# %%
print("accuracy of training data",training_accuracy)
# Out:
# accuracy of training data 0.9479034307496823

# %%
#accuracy on testing data

m_test_prediction = LR.predict(m_test)

testing_accuracy = accuracy_score(m_test_prediction,n_test)

# %%
 #Visualization of confusion matrix (new lines added)
cm = confusion_matrix(n_test, m_test_prediction)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Legitimate', 'Fraudulent'], yticklabels=['Legitimate', 'Fraudulent'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
print("accuracy of testing data ", testing_accuracy)
# Out:
# accuracy of testing data  0.949238578680203
